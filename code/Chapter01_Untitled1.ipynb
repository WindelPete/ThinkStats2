# %%
import nsfg2

# %%
df = nsfg2.ReadFemPreg()
df
# Out:
# C:\Users\Admin\Documents\GitHub\ThinkStats2\code\nsfg2.py:59: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_lb1.replace(na_vals, np.nan, inplace=True)
# C:\Users\Admin\Documents\GitHub\ThinkStats2\code\nsfg2.py:60: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_oz1.replace(na_vals, np.nan, inplace=True)
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       39968         1        NaN        NaN       NaN       NaN       3.0
# 1       39968         2        NaN        NaN       NaN       NaN       3.0
# 2       41474         1        NaN        NaN       NaN       NaN       3.0
# 3       33303         1        NaN        NaN       NaN       NaN       1.0
# 4       33303         2        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 20487   26372         4        NaN        NaN       NaN       NaN       6.0
# 20488   32486         1        NaN        NaN       NaN       NaN       3.0
# 20489   29718         1        NaN        NaN       NaN       NaN       6.0
# 20490   29718         2        NaN        NaN       NaN       NaN       6.0
# 20491   29718         3        NaN        NaN       NaN       NaN       6.0
#
#        pregend2  pregend3  howenddk  ...  secu  sest  cmintvw  cmlstyr  \
# 0           NaN       NaN       NaN  ...     2   105     1323     1311
# 1           NaN       NaN       NaN  ...     2   105     1323     1311
# 2           NaN       NaN       NaN  ...     2   105     1322     1310
# 3           NaN       NaN       NaN  ...     2   105     1289     1277
# 4           NaN       NaN       NaN  ...     2   105     1289     1277
# ...         ...       ...       ...  ...   ...   ...      ...      ...
# 20487       NaN       NaN       NaN  ...     4   156     1286     1274
# 20488       NaN       NaN       NaN  ...     4   156     1283     1271
# 20489       NaN       NaN       NaN  ...     4   156     1282     1270
# 20490       NaN       NaN       NaN  ...     4   156     1282     1270
# 20491       NaN       NaN       NaN  ...     4   156     1282     1270
#
#        cmjan3yr  cmjan5yr  questyear  quarter  phase  totalwgt_lb
# 0          1285      1261          4       15    NaN          NaN
# 1          1285      1261          4       15    NaN          NaN
# 2          1285      1261          4       15    NaN          NaN
# 3          1249      1225          1        4    NaN          NaN
# 4          1249      1225          1        4    NaN       8.5000
# ...         ...       ...        ...      ...    ...          ...
# 20487      1249      1225          1        2    NaN       8.0625
# 20488      1237      1213          1        2    NaN          NaN
# 20489      1237      1213          1        2    NaN       7.0000
# 20490      1237      1213          1        2    NaN       7.5000
# 20491      1237      1213          1        2    NaN       8.0000
#
# [20492 rows x 288 columns]

# %%
pregordr = df["pregordr"]
type(pregordr)
# Out:
# pandas.core.series.Series

# %%
df.columns[20:40]
# Out:
# Index(['mosgest', 'dk1gest', 'dk2gest', 'dk3gest', 'bpa_bdscheck1',
#        'bpa_bdscheck2', 'bpa_bdscheck3', 'babysex1', 'birthwgt_lb1',
#        'birthwgt_oz1', 'lobthwgt1', 'babysex2', 'birthwgt_lb2', 'birthwgt_oz2',
#        'lobthwgt2', 'babysex3', 'birthwgt_lb3', 'birthwgt_oz3', 'lobthwgt3',
#        'babydob_m'],
#       dtype='object')

# %%
print(df.columns[1])
pregordr
# Out:
# pregordr
# 0        1
# 1        2
# 2        1
# 3        1
# 4        2
#         ..
# 20487    4
# 20488    1
# 20489    1
# 20490    2
# 20491    3
# Name: pregordr, Length: 20492, dtype: int64

# %%
pregordr[0]
#type(pregordr[0])
# Out:
# np.int64(1)

# %%
pregordr[2:5]
# Out:
# 2    1
# 3    1
# 4    2
# Name: pregordr, dtype: int64

# %%
df.outcome
# Out:
# 0        2
# 1        2
# 2        2
# 3        4
# 4        1
#         ..
# 20487    1
# 20488    2
# 20489    1
# 20490    1
# 20491    1
# Name: outcome, Length: 20492, dtype: int64

# %%
df.outcome.value_counts()
# Out:
# outcome
# 1    14292
# 4     2945
# 2     2295
# 6      516
# 5      278
# 3      166
# Name: count, dtype: int64

# %%
df.outcome.value_counts().sort_index()
# Out:
# outcome
# 1    14292
# 2     2295
# 3      166
# 4     2945
# 5      278
# 6      516
# Name: count, dtype: int64

# %%
df.birthwgt_lb1.value_counts().sort_index()
# Out:
# birthwgt_lb1
# 0.0       13
# 1.0       82
# 2.0       91
# 3.0      148
# 4.0      359
# 5.0     1095
# 6.0     3385
# 7.0     4955
# 8.0     2861
# 9.0      889
# 10.0     196
# 11.0      36
# 12.0      12
# 13.0       6
# 16.0       1
# Name: count, dtype: int64
