# %% [markdown]
# # Chapter 1
#
# Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from os.path import basename, exists


def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + local)


download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkstats2.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkplot.py")

# %%
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/nsfg.py")

download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dct")
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dat.gz"
)

# %% [markdown]
# ## Examples from Chapter 1
#
# Read NSFG data into a Pandas DataFrame.

# %%
import nsfg2

# %%
preg = nsfg2.ReadFemPreg()
preg.head()
# Out:
# C:\Users\Admin\Documents\GitHub\ThinkStats2\code\nsfg2.py:59: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_lb1.replace(na_vals, np.nan, inplace=True)
# C:\Users\Admin\Documents\GitHub\ThinkStats2\code\nsfg2.py:60: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_oz1.replace(na_vals, np.nan, inplace=True)
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0   39968         1        NaN        NaN       NaN       NaN       3.0
# 1   39968         2        NaN        NaN       NaN       NaN       3.0
# 2   41474         1        NaN        NaN       NaN       NaN       3.0
# 3   33303         1        NaN        NaN       NaN       NaN       1.0
# 4   33303         2        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  pregend3  howenddk  ...  secu  sest  cmintvw  cmlstyr  cmjan3yr  \
# 0       NaN       NaN       NaN  ...     2   105     1323     1311      1285
# 1       NaN       NaN       NaN  ...     2   105     1323     1311      1285
# 2       NaN       NaN       NaN  ...     2   105     1322     1310      1285
# 3       NaN       NaN       NaN  ...     2   105     1289     1277      1249
# 4       NaN       NaN       NaN  ...     2   105     1289     1277      1249
#
#    cmjan5yr  questyear  quarter  phase  totalwgt_lb
# 0      1261          4       15    NaN          NaN
# 1      1261          4       15    NaN          NaN
# 2      1261          4       15    NaN          NaN
# 3      1225          1        4    NaN          NaN
# 4      1225          1        4    NaN          8.5
#
# [5 rows x 288 columns]

# %% [markdown]
# Print the column names.

# %%
preg.columns
# Out:
# Index(['caseid', 'pregordr', 'howpreg_n', 'howpreg_p', 'moscurrp', 'nowprgdk',
#        'pregend1', 'pregend2', 'pregend3', 'howenddk',
#        ...
#        'secu', 'sest', 'cmintvw', 'cmlstyr', 'cmjan3yr', 'cmjan5yr',
#        'questyear', 'quarter', 'phase', 'totalwgt_lb'],
#       dtype='object', length=288)

# %% [markdown]
# Select a single column name.

# %%
preg.columns[1]
# Out:
# 'pregordr'

# %% [markdown]
# Select a column and check what type it is.

# %%
pregordr = preg['pregordr']
type(pregordr)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Print a column.

# %%
pregordr

# %% [markdown]
# Select a single element from a column.

# %%
pregordr[0]

# %% [markdown]
# Select a slice from a column.

# %%
pregordr[2:5]

# %% [markdown]
# Select a column using dot notation.

# %%
pregordr = preg.pregordr

# %% [markdown]
# Count the number of times each value occurs.

# %%
preg.outcome.value_counts().sort_index()

# %% [markdown]
# Check the values of another variable.

# %%
preg.birthwgt_lb.value_counts().sort_index()

# %% [markdown]
# Make a dictionary that maps from each respondent's `caseid` to a list of indices into the pregnancy `DataFrame`.  Use it to select the pregnancy outcomes for a single respondent.

# %%
caseid = 10229
preg_map = nsfg2.MakePregMap(preg)
indices = preg_map[caseid]
preg.outcome[indices].values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 caseid = 10229
# ----> 2 preg_map = nsfg2.MakePregMap(preg)
#       3 indices = preg_map[caseid]
#       4 preg.outcome[indices].values
#
# AttributeError: module 'nsfg2' has no attribute 'MakePregMap'

# %% [markdown]
# ## Exercises

# %% [markdown]
# Select the `birthord` column, print the value counts, and compare to results published in the [codebook](https://ftp.cdc.gov/pub/Health_Statistics/NCHS/Dataset_Documentation/NSFG/Cycle6Codebook-Pregnancy.pdf)

# %%
preg.birthord
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        1.0
#         ...
# 20487    4.0
# 20488    NaN
# 20489    1.0
# 20490    2.0
# 20491    3.0
# Name: birthord, Length: 20492, dtype: float64

# %% [markdown]
# We can also use `isnull` to count the number of nans.

# %%
preg.birthord.isnull().sum()
# Out:
# np.int64(6200)

# %% [markdown]
# Select the `prglngth` column, print the value counts, and compare to results published in the [codebook](https://ftp.cdc.gov/pub/Health_Statistics/NCHS/Dataset_Documentation/NSFG/Cycle6Codebook-Pregnancy.pdf)

# %%
preg["prglngth"].value_counts().sort_index()
# Out:
# prglngth
# 0       11
# 1       19
# 2      117
# 3      219
# 4      561
# 5      274
# 6      896
# 7      271
# 8      513
# 9      770
# 10     275
# 11     173
# 12     248
# 13     685
# 14      79
# 15      88
# 16      53
# 17     241
# 18      36
# 19      45
# 20      39
# 21      24
# 22     174
# 23      14
# 24      45
# 25      24
# 26     151
# 27      29
# 28      59
# 29      36
# 30     248
# 31      44
# 32     173
# 33      69
# 34     164
# 35     558
# 36     636
# 37     848
# 38    1311
# 39    6308
# 40    2285
# 41     910
# 42     553
# 43     185
# 44      19
# 45       3
# 46       4
# 48       3
# 52       1
# 57       1
# Name: count, dtype: int64

# %% [markdown]
# To compute the mean of a column, you can invoke the `mean` method on a Series.  For example, here is the mean birthweight in pounds:

# %%
preg.totalwgt_lb.mean()
# Out:
# np.float64(7.237790178571428)

# %%
preg["totalwgt_lb"].mean()
# Out:
# np.float64(7.237790178571428)

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
preg["totalwgt_kg"]=preg["totalwgt_lb"]*0.4535924

# %%
preg["totalwgt_kg"].mean()
# Out:
# np.float64(3.283006617794643)

# %% [markdown]
# `nsfg.py` also provides `ReadFemResp`, which reads the female respondents file and returns a `DataFrame`:

# %%
download("2002FemResp.dct")
download("2002FemResp.dat.gz")

# %%
resp = nsfg2.ReadFemResp()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 resp = nsfg2.ReadFemResp()
#
# AttributeError: module 'nsfg2' has no attribute 'ReadFemResp'

# %% [markdown]
# `DataFrame` provides a method `head` that displays the first five rows:

# %%
resp.head()

# %% [markdown]
# Select the `age_r` column from `resp` and print the value counts.  How old are the youngest and oldest respondents?

# %% [markdown]
# We can use the `caseid` to match up rows from `resp` and `preg`.  For example, we can select the row from `resp` for `caseid` 2298 like this:

# %%
resp[resp.caseid==2298]

# %% [markdown]
# And we can get the corresponding rows from `preg` like this:

# %%
preg[preg.caseid==2298]

# %% [markdown]
# How old is the respondent with `caseid` 1?

# %% [markdown]
# What are the pregnancy lengths for the respondent with `caseid` 2298?

# %% [markdown]
# What was the birthweight of the first baby born to the respondent with `caseid` 5013?
